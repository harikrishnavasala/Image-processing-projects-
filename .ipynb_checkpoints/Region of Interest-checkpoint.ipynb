# %%
# importing necessary packages
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
img=cv2.imread("E:\\computer_vision\\Harikrishna Github\\Image-processing-projects-\\test_imgs\\green_led2.jpg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (100, 100, 3)

# %%
# creating a white image with numpy
roi_img = np.zeros([100,100,3],dtype = np.uint8)
roi_img.fill(255) # pixel values lies between 0 to 255

# %%
roi_img.shape
# Out:
# (100, 100, 3)

# %%
roi_img[20:80,20:90] = img[10:70,20:90] # first give y....> min and max then x....> xmin and xmax values in both lists
plt.imshow(img)

# %%
plt.imshow(roi_img)
plt.show()
